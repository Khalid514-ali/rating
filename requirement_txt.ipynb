# %% [markdown]
# <a href="https://colab.research.google.com/github/Khalid514-ali/rating/blob/main/requirement_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
streamlit
scikit-learn
pandas
numpy
nltk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13532/2671491091.py in <cell line: 0>()
# ----> 1 streamlit
#       2 scikit-learn
#       3 pandas
#       4 numpy
#       5 nltk
#
# NameError: name 'streamlit' is not defined
